# %%
import torch
import numpy as np
import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data import DataLoader

from itertools import cycle
from tqdm.auto import trange
from tqdm.notebook import tqdm

from matplotlib import cm
import matplotlib.pyplot as plt

from utils import plot_utils, s3w_utils, vmf_utils, utils
from utils.nf_utils import normalizing_flows
from methods import s3w, ssw, sw

from experiments import gf_particles, gd_sphere

from scipy.stats import gaussian_kde

device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

# %%
mu_target = [0,1,0]
mu_target = mu_target / np.linalg.norm(mu_target)

kappa_target = 10

X_target = torch.tensor(vmf_utils.rand_vmf(mu_target, kappa=kappa_target, N=10000), dtype=torch.float)

# %%
plot_utils.plot_all([X_target], ['X_target'], view_init=(25,25))

# %%
target_fn = lambda x : vmf_utils.pdf_vmf(torch.tensor(np.array(x), dtype=torch.float, device=device), 
                               torch.tensor(np.array([mu_target]), dtype=torch.float, device=device), 
                               kappa_target).cpu().numpy()

plot_utils.plot_target_density(target_fn)

# %%
target_fn = lambda x : vmf_utils.pdf_vmf(torch.tensor(np.array(x), dtype=torch.float, device=device), 
                               torch.tensor(np.array([mu_target]), dtype=torch.float, device=device), 
                               kappa_target).cpu().numpy()

fig, ax = plt.subplots(1, 1, subplot_kw={'projection': "mollweide"})
plot_utils.projection_mollweide(target_fn, ax)
plt.show()

# %%
plot_utils.scatter_mollweide(X_target, target_fn)

# %% [markdown]
# ## Gradient Flow on Particles

# %%
X0 = torch.randn((500, 3), device=device)
X0 = F.normalize(X0, p=2, dim=-1)
X0.requires_grad_(True)
L = [X0.clone()]
L_loss = []

# %%
d_func = s3w.s3wd 
d_args = {'p': 2, 'n_projs': 10000, 'device': device}

L, L_loss = gf_particles.run_exp(X_target, X0, d_func , d_args, device, n_steps=1001, lr=1, batch_size=500)
# Out:
# 100%|████████████████████████████████████████████████████| 1001/1001 [00:22<00:00, 43.97it/s, Loss = 5.485]

# %%
for k in [0, 1000]:
    X_target_cpu = X_target.cpu().detach().numpy()
    L_k_cpu = L[k].cpu().detach().numpy()

    datasets = [X_target_cpu, L_k_cpu]
    labels = ['X_target', f'L_{k}']

    plot_utils.plot_all(datasets, labels, view_init=(25, 25))

# %%
plt.plot(L_loss)
plt.show()

# %%
utils.compute_paalc(L_loss, 1001, max(L_loss))
# Out:
# 93.19038412071929

# %%
d_func = ssw.sswd 
d_args = {'p': 2, 'num_projections': 10000, 'device': device}

L, L_loss = gf_particles.run_exp(X_target, X0, d_func , d_args, device, n_steps=1001, lr=100, batch_size=500)
# Out:
# 100%|████████████████████████████████████████████████████| 1001/1001 [22:52<00:00,  1.37s/it, Loss = 0.000]

# %%
for k in [0, 1000]:
    X_target_cpu = X_target.cpu().detach().numpy()
    L_k_cpu = L[k].cpu().detach().numpy()

    datasets = [X_target_cpu, L_k_cpu]
    labels = ['X_target', f'L_{k}']

    plot_utils.plot_all(datasets, labels, view_init=(25, 25))

# %%
plt.plot(L_loss)
plt.show()
