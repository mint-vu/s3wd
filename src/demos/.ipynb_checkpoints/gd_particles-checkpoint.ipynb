# %%
import torch
import numpy as np
import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data import DataLoader

from itertools import cycle
from tqdm.auto import trange

from matplotlib import cm
import matplotlib.pyplot as plt

from utils import plot_utils, s3w_utils, vmf_utils, utils
from utils.nf_utils import normalizing_flows
from methods import s3w, ssw, sw

from experiments import gf_particles, gd_sphere

from scipy.stats import gaussian_kde

device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Gradient Flow on Particles

# %%
mu_target = [0,1,0]
mu_target = mu_target / np.linalg.norm(mu_target)
kappa_target = 10
X_target = torch.tensor(vmf_utils.rand_vmf(mu_target, kappa=kappa_target, N=10000), dtype=torch.float)

# %%
plot_utils.plot_all([X_target], ['X_target'], view_init=(25,25))

# %%
#def sswd(Xs, Xt, num_projections, device, u_weights=None, v_weights=None, p=2):

# %%
X0 = torch.randn((500, 3), device=device)
X0 = F.normalize(X0, p=2, dim=-1)
X0.requires_grad_(True)
L = [X0.clone()]
L_loss = []

# %%
d_func = ssw.sswd 
d_args = {'p': 2, 'num_projections': 10000, 'device': device}
L1, L1_loss = gd_sphere.run_exp(X_target, X0, d_func, d_args, device, n_steps=3000, lr=100)
# Out:
#   0%|                                                       | 4/3000 [00:02<27:26,  1.82it/s, loss = 0.044]

# %%
utils.compute_aalc(L_loss, 5000, max(L_loss))
# Out:
# 324314.4789550598

# %%
utils.compute_aalc(L_loss, 5000, max(L_loss))
# Out:
# 90.39077141868297

# %%
d_func = s3w.s3wd 
d_args = {'p': 2, 'n_projs': 10000, 'device': device}
L, L_loss = gd_sphere.run_exp(X_target, X0, d_func, d_args, device, n_steps=3000, lr=0.01)
# Out:
# 100%|████████████████████████████████████████████████████| 3000/3000 [00:38<00:00, 77.69it/s, loss = 8.459]

# %%
for k in [0, 5000]:
    X_target_cpu = X_target.cpu().detach().numpy()
    L_k_cpu = L[k].cpu().detach().numpy()

    datasets = [X_target_cpu, L_k_cpu]
    labels = ['X_target', f'L_{k}']

    plot_utils.plot_all(datasets, labels, view_init=(25, 25))

# %%
for k in [0, 5000]:
    X_target_cpu = X_target.cpu().detach().numpy()
    L_k_cpu1 = L1[k].cpu().detach().numpy()

    datasets = [X_target_cpu, L_k_cpu1]
    labels = ['X_target', f'L_{k}']

    plot_utils.plot_all(datasets, labels, view_init=(25, 25))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 for k in [0, 5000]:
#       2     X_target_cpu = X_target.cpu().detach().numpy()
# ----> 3     L_k_cpu1 = L1[k].cpu().detach().numpy()
#       5     datasets = [X_target_cpu, L_k_cpu1]
#       6     labels = ['X_target', f'L_{k}']
#
# IndexError: list index out of range
