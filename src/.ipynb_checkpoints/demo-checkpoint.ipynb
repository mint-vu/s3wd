# %%
from methods.s3w import *
from utils import utils, s3w_utils
import numpy as np
import torch
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

device=torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')

# %%
def plot_stuff(s1, s2, n_meridians=20, n_parallels=100):
    fig = plt.figure(figsize=(18, 9))
    ax1 = fig.add_subplot(121, projection='3d')
    ax1.scatter(s1[:, 0], s1[:, 1], s1[:, 2], s=3, c='cyan', label='vMF 1')
    ax1.scatter(s2[:, 0], s2[:, 1], s2[:, 2], s=3, c='red', label='vMF 2')
    ax1.view_init(0, 0)
    ax1.set_xlim(-1.5, 1.5)
    ax1.set_ylim(-1.5, 1.5)
    ax1.set_zlim(-1.5, 1.5)

    u, v = np.mgrid[0:2*np.pi:100j, 0:np.pi:100j]
    x = np.cos(u) * np.sin(v)
    y = np.sin(u) * np.sin(v)
    z = np.cos(v)
    ax1.plot_surface(x, y, z, color='grey', alpha=0.3)
    
    ax1.grid(False)
    ax1.legend()
    ax1.set_xticks([-1, 0, 1])
    ax1.set_yticks([-1, 0, 1])
    ax1.set_zticks([-1, 0, 1])

    ax2 = fig.add_subplot(122)
    s1_p = get_stereo_proj(s1)
    s2_p = get_stereo_proj(s2)
    ax2.scatter(s1_p[:, 0], s1_p[:, 1], s=3, c='cyan', label='sp1')
    ax2.scatter(s2_p[:, 0], s2_p[:, 1], s=3, c='red', label='sp2')

    s_p = np.concatenate((s1_p, s2_p), axis=0)
    max_extent = np.max(np.abs(s_p)) * 0.5
    ax2.set_xlim(-max_extent, max_extent)
    ax2.set_ylim(-max_extent, max_extent)

    for i in range(n_meridians):
        phi = i * 2 * np.pi / n_meridians
        meridian = np.array([[np.sin(theta) * np.cos(phi), np.sin(theta) * np.sin(phi), np.cos(theta)] for theta in np.linspace(0, np.pi, 100)])
        proj_meridian = get_stereo_proj(meridian)
        ax2.plot(proj_meridian[:, 0], proj_meridian[:, 1], color='black', alpha=0.5,lw=0.1)

    for j in range(n_parallels):
        theta = j * np.pi / n_parallels
        parallel = np.array([[np.sin(theta) * np.cos(phi), np.sin(theta) * np.sin(phi), np.cos(theta)] for phi in np.linspace(0, 2 * np.pi, 100)])
        proj_parallel = get_stereo_proj(parallel)
        ax2.plot(proj_parallel[:, 0], proj_parallel[:, 1], color='grey', alpha=0.5,lw=0.1)

    ax2.legend()

    plt.show()

# %%
mu1 = np.array([0, 0, -1])
mu2 = np.array([0,0,1])
kappa = 1
N = 100
s1 = utils.rand_vmf(mu1, kappa, N)
s2 = utils.rand_vmf(mu2, kappa, N)

# %%
# logmap = s3w_utils.LogMap(s1.size(-1)-1).to(device)

# %%
s3w = s3wd(s1, s2, p=2, h=None, n_projs=2000, device=device)
# maxs3w = max_s3wd(s1, s2, p=2, n_projs=2000, lam=20, n_iters=1000, device=device)
print(s3w)#, maxs3w)
ps1 = get_stereo_proj(s1)
ps2 = get_stereo_proj(s2)

plot_stuff(s1,s2)
# Out:
# tensor(24.2774, device='cuda:1', dtype=torch.float64)

# %%
def slerp(s1, s2, t):
    omegas = torch.acos(torch.clamp(torch.sum(s1 * s2, dim=1), -1, 1))
    sos = torch.sin(omegas)
    return torch.sin((1.0 - t) * omegas).unsqueeze(-1) / sos.unsqueeze(-1) * s1 + torch.sin(t * omegas).unsqueeze(-1) / sos.unsqueeze(-1) * s2

def plot_sphere(ax):
    u, v = np.mgrid[0:2*np.pi:20j, 0:np.pi:10j]
    x = np.cos(u)*np.sin(v)
    y = np.sin(u)*np.sin(v)
    z = np.cos(v)
    ax.plot_wireframe(x, y, z, color="gray", alpha=0.1)

mu1 = np.array([-20, 0, -1])
mu2 = np.array([20,2,2])
kappa = 10
N = 100 


s1 = torch.tensor(utils.rand_vmf(mu1, kappa, N), requires_grad=False)
s2 = torch.tensor(utils.rand_vmf(mu2, 2*kappa, N), requires_grad=False)

n_steps = 15
rows = int(np.ceil(n_steps / 4))
fig = plt.figure(figsize=(4 * 4, 4 * rows))

for i in range(n_steps):
    ax = fig.add_subplot(rows, 4, i + 1, projection='3d')
    t = i / (n_steps - 1)
    s_interp = slerp(s1, s2, t)

    s3w = s3wd(s1, s_interp, p=2, n_projs=2000, device=device)

    plot_sphere(ax)
    ax.scatter(s1[:, 0], s1[:, 1], s1[:, 2], color='blue', label='s1',s=1)
    ax.scatter(s2[:, 0], s2[:, 1], s2[:, 2], color='red', label='s2',s=2)
    ax.scatter(s_interp[:, 0], s_interp[:, 1], s_interp[:, 2], color='gray',s=10, alpha=0.5, label='interp')


    ax.set_xlim([-1, 1])
    ax.set_ylim([-1, 1])
    ax.set_zlim([-1, 1])
    ax.axis('off')
    ax.set_title(f'Step {i+1}, S3W(s1,s1_interp)={s3w.item():.4f}')

plt.tight_layout()
plt.show()
